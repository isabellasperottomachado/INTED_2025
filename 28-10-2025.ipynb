# %% [markdown]
# <a href="https://colab.research.google.com/github/isabellasperottomachado/INTED_2025/blob/main/28-10-2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 - Peça um número e informe se ele é maior que 10. Crie um algoritmo em Python para fazer essa verificação.
idade= int(input('digite uma idade:'))
if idade>10:
  print("maior de idade")
# Out:
# digite uma idade:15
# maior de idade

# %%
#2 - Peça um número inteiro e informe se ele é par. Crie um algoritmo em Python que verifique se o número é divisível por 2.
número= int(input('digite um número:'))
if número%2==0:
  print('par')
else:
  print('impar')
# Out:
# digite um número:12
# par

# %%
#3 - Peça um nome e informe se ele contém a letra "a". Crie um algoritmo em Python que faça essa verificação.
nome= input('Digite um nome:')
if 'a' in nome.lower():
  print("o nome contém a letra 'a'")
else:
  print("outro nome não contém a letra 'a'")
# Out:
# Digite um nome:isabella
# o nome contém a letra 'a'

# %%
#4 - Peça um número e informe se ele é múltiplo de 5. Crie um algoritmo em Python que verifique se o número é divisível por 5.
num1= int(input('digite um número:'))
if num1%5==0:
  print("o num1 é multiplo de '5'")
else:
  print("o número não é multiplo de '5'")
# Out:
# digite um número:625
# o num1 é multiplo de '5'

# %%
#5 - Peça a temperatura atual e informe se está quente (acima de 30°C) ou frio (30°C ou menos). Crie um algoritmo em Python para essa verificação.
temp= int(input('digite a tempertura atual: '))
if temp>30:
  print('está quente')
else:
  print('está frio')
# Out:
# digite a tempertura atual: 16
# está frio

# %%
#6 - Peça ao usuário para digitar "S" para continuar ou "N" para sair e informe a ação correspondente. Crie um algoritmo em Python que faça essa validação e exiba a mensagem correta.
acao= input("digite 's' para continuar ou 'n' para sair: ")
if acao=='s':
  print("'s' continuar")
elif acao == "n":
  print("'n' sair")
else:
  print("entrada invalida. Por favor digite 's' ou 'n'")
# Out:
# digite 's' para continuar ou 'n' para sair: n
# 'n' sair

# %%
#7 - Peça um número e informe se ele é negativo, zero ou positivo. Crie um algoritmo em Python para classificar o número.
num= int(input('digite um número:'))
if num<0:
  print('número negativo')
elif num==0:
  print('número zero')
else:
  print('número positivo')
# Out:
# digite um número:12
# número positivo

# %%
#8 - Peça um número de 1 a 7 e informe o dia da semana correspondente. Crie um algoritmo em Python que associe o número ao dia correto.
num= int(input('Digite um número de 1 a 7 informando o dia da semana correspondente'))
if num==1:
  print('domingo')
elif num ==2:
  print('segunda-feira')
elif num==3:
  print('terça -feira')
elif num==4:
  print('quara-feira')
elif num==5:
  print('quinta-feira')
elif num==6:
  print('sexta-feira')
elif num==7
  print('sábado')
# Out:
#   File "/tmp/ipython-input-4254095023.py", line 15
#     elif num==7
#                ^
# SyntaxError: expected ':'
